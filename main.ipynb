# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("tourist_expenditure_dataset.csv")

# %%
df
# Out:
#         Tourist ID Country of Origin Destination Country  Hotel Expenditure  \
# 0              1.0           Germany           Australia             242.19
# 1              2.0             India           Australia             465.22
# 2              3.0                UK               Italy             117.06
# 3              4.0             India           Australia             331.98
# 4              5.0             India               Spain             307.31
# ...            ...               ...                 ...                ...
# 100000     75722.0             India                 USA             485.37
# 100001     80185.0            Canada              France             223.98
# 100002     19865.0               USA                 USA             467.62
# 100003         NaN            Canada               Spain             423.36
# 100004     92992.0             India              France             184.89
#
#         Food Expenditure  Entertainment Expenditure  Transport Expenditure  \
# 0                  87.35                     107.86                  80.93
# 1                  87.94                     132.20                  90.23
# 2                  92.05                      72.82                  73.79
# 3                  63.87                     103.04                    NaN
# 4                  46.41                     105.15                  51.86
# ...                  ...                        ...                    ...
# 100000             90.49                      49.71                  75.33
# 100001             26.02                      78.78                  66.26
# 100002             46.03                     137.60                  64.84
# 100003             81.84                      71.92                  91.00
# 100004             49.40                      77.83                  54.88
#
#         Total Expenditure  Trip Duration  Age of Tourist  Gender  Season  \
# 0                  518.33           11.0            28.0  Female  Summer
# 1                  775.59            8.0            45.0  Female  Summer
# 2                  355.72            3.0            33.0  Female  Autumn
# 3                  585.05            5.0            42.0    Male  Summer
# 4                  510.73           12.0            56.0    Male  Winter
# ...                   ...            ...             ...     ...     ...
# 100000             700.90            9.0            27.0    Male  Autumn
# 100001             395.04           12.0            57.0  Female  Winter
# 100002             716.09            7.0            26.0  Female  Spring
# 100003             668.12            5.0            69.0  Female  Spring
# 100004             367.00            4.0            46.0    Male  Autumn
#
#         Satisfaction Rating
# 0                       NaN
# 1                       2.0
# 2                       5.0
# 3                       5.0
# 4                       4.0
# ...                     ...
# 100000                  4.0
# 100001                  3.0
# 100002                  4.0
# 100003                  2.0
# 100004                  1.0
#
# [100005 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Tourist ID                   6831
# Country of Origin               0
# Destination Country             0
# Hotel Expenditure            5000
# Food Expenditure             5000
# Entertainment Expenditure    5000
# Transport Expenditure        5000
# Total Expenditure            5000
# Trip Duration                5000
# Age of Tourist               5000
# Gender                          0
# Season                          0
# Satisfaction Rating          5000
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Tourist ID                   0
# Country of Origin            0
# Destination Country          0
# Hotel Expenditure            0
# Food Expenditure             0
# Entertainment Expenditure    0
# Transport Expenditure        0
# Total Expenditure            0
# Trip Duration                0
# Age of Tourist               0
# Gender                       0
# Season                       0
# Satisfaction Rating          0
# dtype: int64

# %%
df.dtypes
# Out:
# Tourist ID                   float64
# Country of Origin             object
# Destination Country           object
# Hotel Expenditure            float64
# Food Expenditure             float64
# Entertainment Expenditure    float64
# Transport Expenditure        float64
# Total Expenditure            float64
# Trip Duration                float64
# Age of Tourist               float64
# Gender                        object
# Season                        object
# Satisfaction Rating          float64
# dtype: object

# %%
df
# Out:
#         Tourist ID Country of Origin Destination Country  Hotel Expenditure  \
# 1              2.0             India           Australia             465.22
# 2              3.0                UK               Italy             117.06
# 4              5.0             India               Spain             307.31
# 5              6.0            Canada           Australia             195.72
# 8              9.0                UK               Italy             251.76
# ...            ...               ...                 ...                ...
# 99993      99994.0           Germany           Australia             432.96
# 100000     75722.0             India                 USA             485.37
# 100001     80185.0            Canada              France             223.98
# 100002     19865.0               USA                 USA             467.62
# 100004     92992.0             India              France             184.89
#
#         Food Expenditure  Entertainment Expenditure  Transport Expenditure  \
# 1                  87.94                     132.20                  90.23
# 2                  92.05                      72.82                  73.79
# 4                  46.41                     105.15                  51.86
# 5                  21.03                     109.43                  99.62
# 8                  77.88                     103.19                  56.72
# ...                  ...                        ...                    ...
# 99993              86.61                      84.05                  56.51
# 100000             90.49                      49.71                  75.33
# 100001             26.02                      78.78                  66.26
# 100002             46.03                     137.60                  64.84
# 100004             49.40                      77.83                  54.88
#
#         Total Expenditure  Trip Duration  Age of Tourist  Gender  Season  \
# 1                  775.59            8.0            45.0  Female  Summer
# 2                  355.72            3.0            33.0  Female  Autumn
# 4                  510.73           12.0            56.0    Male  Winter
# 5                  425.80            7.0            39.0    Male  Spring
# 8                  489.55            4.0            26.0  Female  Summer
# ...                   ...            ...             ...     ...     ...
# 99993              660.13            7.0            69.0    Male  Summer
# 100000             700.90            9.0            27.0    Male  Autumn
# 100001             395.04           12.0            57.0  Female  Winter
# 100002             716.09            7.0            26.0  Female  Spring
# 100004             367.00            4.0            46.0    Male  Autumn
#
#         Satisfaction Rating
# 1                       2.0
# 2                       5.0
# 4                       4.0
# 5                       4.0
# 8                       3.0
# ...                     ...
# 99993                   4.0
# 100000                  4.0
# 100001                  3.0
# 100002                  4.0
# 100004                  1.0
#
# [61840 rows x 13 columns]

# %%
df = pd.read_csv("Tourist_expenditure_dataset.csv")
print(df.columns)
for col in df.select_dtypes(include=["number"]).columns:  
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]
# Out:
# Index(['Tourist ID', 'Country of Origin', 'Destination Country',
#        'Hotel Expenditure', 'Food Expenditure', 'Entertainment Expenditure',
#        'Transport Expenditure', 'Total Expenditure', 'Trip Duration',
#        'Age of Tourist', 'Gender', 'Season', 'Satisfaction Rating'],
#       dtype='object')

# %%
df
# Out:
#         Tourist ID Country of Origin Destination Country  Hotel Expenditure  \
# 1              2.0             India           Australia             465.22
# 2              3.0                UK               Italy             117.06
# 4              5.0             India               Spain             307.31
# 5              6.0            Canada           Australia             195.72
# 8              9.0                UK               Italy             251.76
# ...            ...               ...                 ...                ...
# 99993      99994.0           Germany           Australia             432.96
# 100000     75722.0             India                 USA             485.37
# 100001     80185.0            Canada              France             223.98
# 100002     19865.0               USA                 USA             467.62
# 100004     92992.0             India              France             184.89
#
#         Food Expenditure  Entertainment Expenditure  Transport Expenditure  \
# 1                  87.94                     132.20                  90.23
# 2                  92.05                      72.82                  73.79
# 4                  46.41                     105.15                  51.86
# 5                  21.03                     109.43                  99.62
# 8                  77.88                     103.19                  56.72
# ...                  ...                        ...                    ...
# 99993              86.61                      84.05                  56.51
# 100000             90.49                      49.71                  75.33
# 100001             26.02                      78.78                  66.26
# 100002             46.03                     137.60                  64.84
# 100004             49.40                      77.83                  54.88
#
#         Total Expenditure  Trip Duration  Age of Tourist  Gender  Season  \
# 1                  775.59            8.0            45.0  Female  Summer
# 2                  355.72            3.0            33.0  Female  Autumn
# 4                  510.73           12.0            56.0    Male  Winter
# 5                  425.80            7.0            39.0    Male  Spring
# 8                  489.55            4.0            26.0  Female  Summer
# ...                   ...            ...             ...     ...     ...
# 99993              660.13            7.0            69.0    Male  Summer
# 100000             700.90            9.0            27.0    Male  Autumn
# 100001             395.04           12.0            57.0  Female  Winter
# 100002             716.09            7.0            26.0  Female  Spring
# 100004             367.00            4.0            46.0    Male  Autumn
#
#         Satisfaction Rating
# 1                       2.0
# 2                       5.0
# 4                       4.0
# 5                       4.0
# 8                       3.0
# ...                     ...
# 99993                   4.0
# 100000                  4.0
# 100001                  3.0
# 100002                  4.0
# 100004                  1.0
#
# [61159 rows x 13 columns]

# %%
df["Tourist ID"]=df["Tourist ID"].astype(int)
df["Age of Tourist"]=df["Age of Tourist"].astype(int)
df["Trip Duration"]=df["Trip Duration"].astype(int)

# %%
df
# Out:
#         Tourist ID Country of Origin Destination Country  Hotel Expenditure  \
# 1                2             India           Australia             465.22
# 2                3                UK               Italy             117.06
# 4                5             India               Spain             307.31
# 5                6            Canada           Australia             195.72
# 8                9                UK               Italy             251.76
# ...            ...               ...                 ...                ...
# 99993        99994           Germany           Australia             432.96
# 100000       75722             India                 USA             485.37
# 100001       80185            Canada              France             223.98
# 100002       19865               USA                 USA             467.62
# 100004       92992             India              France             184.89
#
#         Food Expenditure  Entertainment Expenditure  Transport Expenditure  \
# 1                  87.94                     132.20                  90.23
# 2                  92.05                      72.82                  73.79
# 4                  46.41                     105.15                  51.86
# 5                  21.03                     109.43                  99.62
# 8                  77.88                     103.19                  56.72
# ...                  ...                        ...                    ...
# 99993              86.61                      84.05                  56.51
# 100000             90.49                      49.71                  75.33
# 100001             26.02                      78.78                  66.26
# 100002             46.03                     137.60                  64.84
# 100004             49.40                      77.83                  54.88
#
#         Total Expenditure  Trip Duration  Age of Tourist  Gender  Season  \
# 1                  775.59              8              45  Female  Summer
# 2                  355.72              3              33  Female  Autumn
# 4                  510.73             12              56    Male  Winter
# 5                  425.80              7              39    Male  Spring
# 8                  489.55              4              26  Female  Summer
# ...                   ...            ...             ...     ...     ...
# 99993              660.13              7              69    Male  Summer
# 100000             700.90              9              27    Male  Autumn
# 100001             395.04             12              57  Female  Winter
# 100002             716.09              7              26  Female  Spring
# 100004             367.00              4              46    Male  Autumn
#
#         Satisfaction Rating
# 1                       2.0
# 2                       5.0
# 4                       4.0
# 5                       4.0
# 8                       3.0
# ...                     ...
# 99993                   4.0
# 100000                  4.0
# 100001                  3.0
# 100002                  4.0
# 100004                  1.0
#
# [61159 rows x 13 columns]

# %% [markdown]
# **DATA ANALYISIS**

# %%
# Group by Age and compute average Trip Duration
age_trip_duration = df.groupby("Age of Tourist")["Trip Duration"].mean()

# Create a Line Graph
plt.figure(figsize=(8, 5))
plt.plot(age_trip_duration.index, age_trip_duration.values, marker="o", linestyle="-", color="g", linewidth=2, markersize=6)

# Labels and title
plt.title("Trip Duration vs. Age of Tourists")
plt.xlabel("Age of Tourist")
plt.ylabel("Average Trip Duration (Days)")
plt.grid(True, linestyle="--", alpha=0.7)

# Show the plot
plt.show()

# %%
# Horizontal Box Plot using Matplotlib
plt.figure(figsize=(10, 4))
plt.boxplot(df["Total Expenditure"], vert=False, patch_artist=True, boxprops=dict(facecolor="lightblue"))

# Labels and title
plt.title("Box Plot of Total Expenditure")
plt.xlabel("Total Expenditure")
plt.grid(True)

# Show plot
plt.show()

# %%
## This suggests a right-skewed (positively skewed) distribution, meaning:
## Most tourists spend between 367.60 and 593.29.
## A few tourists spend significantly more, pulling the median lower.

# %%
total_expenditure_data = df["Total Expenditure"].to_numpy()
total_expenditure = np.nansum(total_expenditure_data)
print("total expenditure is:",total_expenditure)
# Out:
# total expenditure is: 29389696.0

# %%
country_data = df["Country of Origin"].to_numpy()
season_data = df["Season"].to_numpy()

# %%
unique_countries = np.unique(country_data) 
country_expenditure = {country: np.nansum(total_expenditure_data[np.where(country_data == country)]) for country in unique_countries}

print("\nTotal Expenditure by Country of Origin:")
for country, exp in country_expenditure.items():
    print(f"{country}: {exp}")
# Out:
# Total Expenditure by Country of Origin:
# Canada: 4916462.37
# China: 4884565.61
# Germany: 4981302.57
# India: 4918779.68
# UK: 4788105.4799999995
# USA: 4900480.29

# %%
# Data
countries = ['Canada', 'China', 'Germany', 'India', 'UK', 'USA']
expenditure = [4916462.37, 4884565.61, 4981302.57, 4918779.68, 4788105.47, 4900480.29]

# Create a horizontal bar graph
plt.figure(figsize=(10, 6))
plt.barh(countries, expenditure, color='skyblue')

# Adding title and labels
plt.title('Total Expenditure by Country of Origin')
plt.xlabel('Expenditure')
plt.ylabel('Country')

# Adjusting x-axis limits for better visibility
plt.xlim(min(expenditure) - 500000, max(expenditure) + 500000)

# Adding gridlines to make the differences clearer
plt.grid(True, axis='x', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# ## highest and lowest spending country

# %%
country_expenditure = {
    "Canada": 4916462.37,
    "China": 4884565.61,
    "Germany": 4981302.57,
    "India": 4918779.68,
    "UK": 4788105.48,
    "USA": 4900480.29
}

max_country = max(country_expenditure, key=country_expenditure.get)
min_country = min(country_expenditure, key=country_expenditure.get)

print(f"Highest Spending Country: {max_country} (${country_expenditure[max_country]:,.2f})")
print(f"Lowest Spending Country: {min_country} (${country_expenditure[min_country]:,.2f})")
# Out:
# Highest Spending Country: Germany ($4,981,302.57)
# Lowest Spending Country: UK ($4,788,105.48)

# %% [markdown]
# # SEASONS VS EXPENDITURE

# %%
unique_seasons = np.unique(season_data)  
season_expenditure = {season: np.nansum(total_expenditure_data[season_data == season]) for season in unique_seasons}

print("\nTotal Expenditure by Season:")
for season, exp in season_expenditure.items():
    print(f"{season}: {exp}")
# Out:
# Total Expenditure by Season:
# Autumn: 7449318.83
# Spring: 7376506.15
# Summer: 7322658.03
# Winter: 7241212.99

# %%
import matplotlib.pyplot as plt

# Data
seasons = ['Autumn', 'Spring', 'Summer', 'Winter']
expenditure = [7449318.83, 7376506.15, 7322658.03, 7241212.99]

# Create a vertical bar graph
plt.figure(figsize=(10, 6))
plt.bar(seasons, expenditure, color='lightcoral')

# Adding title and labels
plt.title('Total Expenditure by Season')
plt.xlabel('Season')
plt.ylabel('Expenditure')

# Adjusting y-axis limits to start from 0
plt.ylim(0, max(expenditure) + 500000)

# Adding gridlines to make the differences clearer
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# ## EXPENDITURE IN A PIE CHART

# %%
categories = ["Hotel Expenditure", "Food Expenditure", "Entertainment Expenditure", "Transport Expenditure"]
expenditure_data = df[categories].to_numpy()
total_expenditure_data = df["Total Expenditure"].to_numpy()
category_totals = np.nansum(expenditure_data, axis=0)
total_expenditure = np.nansum(total_expenditure_data)
category_percentages = (category_totals / total_expenditure) * 100
for cat, perc in zip(categories, category_percentages):
    print(f"{cat}: {perc:.2f}%")
# Out:
# Hotel Expenditure: 57.31%
# Food Expenditure: 12.50%
# Entertainment Expenditure: 18.74%
# Transport Expenditure: 11.46%

# %%
labels = ['Hotel Expenditure', 'Food Expenditure', 'Entertainment Expenditure', 'Transport Expenditure']
sizes = [57.31, 12.50, 18.74, 11.46]
colors = ['gold', 'lightcoral', 'lightskyblue', 'lightgreen']

# Plot pie chart
plt.figure(figsize=(7, 7)) #---> 7 inches by 7 inches
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.2f%%', startangle=140) #---> auto pct displays% value and number of decimal points 
plt.title('Expenditure Distribution')
plt.show()

# %% [markdown]
# ## AGE WISE EXPENDITURE

# %%
ages = np.array(df['Age of Tourist'])
expenditures = np.array(df['Total Expenditure'])
age_bins = np.array([18, 25, 35, 45, 55, 65, 75, 100])
age_labels = ["18-25", "26-35", "36-45", "46-55", "56-65", "66-75", "76+"]
age_indices = np.digitize(ages, age_bins, right=False) - 1  
unique_age_groups = np.arange(len(age_labels))  
age_expenditure = np.array([np.sum(expenditures[age_indices == i]) for i in unique_age_groups])
age_count = np.array([np.sum(age_indices == i) for i in unique_age_groups])
avg_expenditure_age = np.divide(age_expenditure, age_count, out=np.zeros_like(age_expenditure), where=age_count > 0)
print("Age-wise Spending Trends:")
for i, age_group in enumerate(age_labels):
    print(f"Age Group {age_group}: Total Expenditure = {age_expenditure[i]:.2f}, Average Expenditure = {avg_expenditure_age[i]:.2f}")
# Out:
# Age-wise Spending Trends:
# Age Group 18-25: Total Expenditure = 3982422.94, Average Expenditure = 480.62
# Age Group 26-35: Total Expenditure = 5688329.47, Average Expenditure = 479.70
# Age Group 36-45: Total Expenditure = 5711935.81, Average Expenditure = 480.72
# Age Group 46-55: Total Expenditure = 5549811.11, Average Expenditure = 481.04
# Age Group 56-65: Total Expenditure = 5650109.80, Average Expenditure = 480.12
# Age Group 66-75: Total Expenditure = 2807086.87, Average Expenditure = 481.66
# Age Group 76+: Total Expenditure = 0.00, Average Expenditure = 0.00

# %%
# Data for Age Group Expenditure
age_groups = ['18-25', '26-35', '36-45', '46-55', '56-65', '66-75']
total_expenditure = [3982422.94, 5688329.47, 5711935.81, 5549811.11, 5650109.80, 2807086.87]
average_expenditure = [480.62, 479.70, 480.72, 481.04, 480.12, 481.66]

# Plot Age Group Expenditure
fig, ax1 = plt.subplots(figsize=(9, 6)) #first axes ax1

ax1.bar(age_groups, total_expenditure, color='skyblue', label='Total Expenditure')
ax1.set_xlabel('Age Groups')
ax1.set_ylabel('Total Expenditure', color='blue')
# ax1.tick_params(axis='y', labelcolor='blue') ##first axis is painted blue if used
plt.title('Age Group Expenditure Analysis')

ax2 = ax1.twinx() ## there are two y axis but when we use twinx it uses the same x axis 
ax2.plot(age_groups, average_expenditure, color='red', marker='o', linestyle='dashed', label='Average Expenditure')
ax2.set_ylabel('Average Expenditure', color='red')
ax2.tick_params(axis='y', labelcolor='red')

fig.legend(loc='upper left')
plt.show()

# %%
# max_age_group_index = np.argmax(avg_expenditure_age)
# highest_spending_age_group = age_labels[max_age_group_index]
# max_gender_index = np.argmax(avg_expenditure_gender)
# highest_spending_gender = unique_genders[max_gender_index]
# print(f"\nOlder vs. Younger Tourists: The highest spending age group is **{highest_spending_age_group}**.\n")
# print("Gender-based Spending Differences:")
# for i, gender in enumerate(unique_genders):
#     print(f"Gender {gender}: Total Expenditure = {gender_expenditure[i]:.2f}, Average Expenditure = {avg_expenditure_gender[i]:.2f}")
# print(f"\nMales vs. Females: The higher spending gender is **{highest_spending_gender}**.\n")

# %% [markdown]
# **YESMA**

# %% [markdown]
# # AVERAGE TRIP DURATION IN SEASON AND COUNTRY

# %%
countries = np.array(df["Country of Origin"])
trip_durations = np.array(df["Trip Duration"])
seasons = np.array(df["Season"])
unique_countries = np.unique(countries)
avg_trip_duration_by_country = np.array([np.mean(trip_durations[countries == country]) for country in unique_countries])
unique_seasons = np.unique(seasons)
avg_trip_duration_by_season = np.array([np.mean(trip_durations[seasons == season]) for season in unique_seasons])
print("Average Trip Duration in Country:")
for country, avg_duration in zip(unique_countries, avg_trip_duration_by_country):
    print(f"{country}: {avg_duration:.2f} days")
print("\nAverage Trip Duration in Season:")
for season, avg_duration in zip(unique_seasons, avg_trip_duration_by_season):
    print(f"{season}: {avg_duration:.2f} days")
# Out:
# Average Trip Duration in Country:
# Canada: 7.96 days
# China: 8.04 days
# Germany: 7.99 days
# India: 8.04 days
# UK: 7.99 days
# USA: 8.03 days
#
# Average Trip Duration in Season:
# Autumn: 8.00 days
# Spring: 8.01 days
# Summer: 8.03 days
# Winter: 7.99 days

# %% [markdown]
# **YESMA**

# %%
hotel_exp = np.array(df["Hotel Expenditure"])
food_exp = np.array(df["Food Expenditure"])
entertainment_exp = np.array(df["Entertainment Expenditure"])
transport_exp = np.array(df["Transport Expenditure"])
total_exp = np.array(df["Total Expenditure"])
trip_duration = np.array(df["Trip Duration"])
satisfaction = np.array(df["Satisfaction Rating"])  # Ensure this is numerical

# Stack data into a single NumPy array (rows = variables, columns = observations)
data_matrix = np.array([hotel_exp, food_exp, entertainment_exp, transport_exp, total_exp, trip_duration, satisfaction])

# Compute the correlation matrix
correlation_matrix = np.corrcoef(data_matrix)

# Print correlation between Total Expenditure & Satisfaction
correlation_expenditure_satisfaction = np.corrcoef(total_exp, satisfaction)[0, 1]

# Display results
# print("\nCorrelation Matrix:")
# print(correlation_matrix)

print(f"\nCorrelation between Total Expenditure and Satisfaction: {correlation_expenditure_satisfaction:.2f}")
# Out:
# Correlation between Total Expenditure and Satisfaction: 0.01

# %%
# Stack data into a single NumPy array (rows = variables, columns = observations)
data_matrix = np.array([hotel_exp, food_exp, entertainment_exp, transport_exp, total_exp, trip_duration, satisfaction])

# Compute the correlation matrix
correlation_matrix = np.corrcoef(data_matrix)

# Create the heatmap using matplotlib
fig, ax = plt.subplots(figsize=(8, 6))
cax = ax.matshow(correlation_matrix, cmap='coolwarm')

# Add color bar
fig.colorbar(cax)

# Set the ticks and labels
ax.set_xticks(np.arange(len(data_matrix)))
ax.set_yticks(np.arange(len(data_matrix)))
ax.set_xticklabels(["Hotel", "Food", "Entertainment", "Transport", "Total Expenditure", "Trip Duration", "Satisfaction"])
ax.set_yticklabels(["Hotel", "Food", "Entertainment", "Transport", "Total Expenditure", "Trip Duration", "Satisfaction"])

# Rotate the x-axis labels for better visibility
plt.xticks(rotation=45)

# Add a title
plt.title('Correlation Matrix Heatmap')

# Show the plot
plt.show()

# Optionally, print the correlation between Total Expenditure and Satisfaction
correlation_expenditure_satisfaction = np.corrcoef(total_exp, satisfaction)[0, 1]
print(f"\nCorrelation between Total Expenditure and Satisfaction: {correlation_expenditure_satisfaction:.2f}")
# Out:
# Correlation between Total Expenditure and Satisfaction: 0.01
